# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
from simpledbf import Dbf5
# Out:
# PyTables is not installed. No support for HDF output.
# SQLalchemy is not installed. No support for SQL output.

# %%
od41_fileloc = 'DataDonwloaded/EOD_from_Louiselle/dep_mtl_2023_02_no16_ten_1841_b2/dep_mtl_2023_02_no16_ten_1841_b2.dbf'
od_file = "DataDonwloaded/EOD_from_Louiselle/EOD/mtl18pv2c.csv"
od = pd.read_csv(od_file,delimiter=';',low_memory=False)
dbf = Dbf5(od41_fileloc)
od41 = dbf.to_dataframe()

# %%
od
# Out:
#          ipere         idu version media_int provenance    date_int  \
# 0            1  1010060100   18.2c         T          F  2018-09-05
# 1            2  1010060201   18.2c         T          F  2018-09-05
# 2            3  1010060202   18.2c         T          F  2018-09-05
# 3            4  1010210101   18.2c         T          F  2018-09-05
# 4            5  1010210102   18.2c         T          F  2018-09-05
# ...        ...         ...     ...       ...        ...         ...
# 393821  393822  8102580103   18.2c         W          W  2018-12-24
# 393822  393823  8102580201   18.2c         W          W  2018-12-24
# 393823  393824  8102580202   18.2c         W          W  2018-12-24
# 393824  393825  8102580301   18.2c         W          W  2018-12-24
# 393825  393826  8102580302   18.2c         W          W  2018-12-24
#
#        deb_interv   nolog  tlog  nbper  ...  busscol  taxi  train  a_pied  \
# 0           01:22  101006   1.0      2  ...      NaN   NaN    NaN     NaN
# ...

# %%
od41
# Out:
#          IPERE  FMEN18E  FPER18E  FPER18MCE  FDEP18E  FMEN21  FMEN26  FMEN31  \
# 0           38    31.82    24.75      24.75    24.75   33.63   35.32   35.69
# 1           18    51.01    49.83      49.83    49.83   51.90   51.91   52.30
# 2           31    34.01    26.08      26.08    26.25   36.13   37.44   37.44
# 3          114    41.42    43.29      43.29    43.81   42.01   42.15   42.16
# 4          364    32.17    26.53      26.53    27.09   32.87   33.17   33.98
# ...        ...      ...      ...        ...      ...     ...     ...     ...
# 393821  314480    33.76    29.67      29.67    29.91   34.22   34.22   34.37
# 393822  314514    23.20    18.95      18.95    19.31   23.38   23.27   24.57
# 393823  314675    40.36    50.52      50.52    50.52   41.77   41.77   41.77
# 393824  314733    21.76    21.35      21.35    21.44   22.46   22.59   22.59
# 393825  314795    33.62    34.76      34.76    35.84   34.29   34.14   34.25
#
# ...

# %%
od = od.merge(od41, how='left',left_on='ipere',right_on='IPERE')
od.to_csv('DataDonwloaded/EOD_from_Louiselle/dep_mtl_2023_02_no16_ten_1841_b2/enhancedOd.csv',index=False)

# %%
od
# Out:
#          ipere         idu version media_int provenance    date_int  \
# 0            1  1010060100   18.2c         T          F  2018-09-05
# 1            2  1010060201   18.2c         T          F  2018-09-05
# 2            3  1010060202   18.2c         T          F  2018-09-05
# 3            4  1010210101   18.2c         T          F  2018-09-05
# 4            5  1010210102   18.2c         T          F  2018-09-05
# ...        ...         ...     ...       ...        ...         ...
# 393821  393822  8102580103   18.2c         W          W  2018-12-24
# 393822  393823  8102580201   18.2c         W          W  2018-12-24
# 393823  393824  8102580202   18.2c         W          W  2018-12-24
# 393824  393825  8102580301   18.2c         W          W  2018-12-24
# 393825  393826  8102580302   18.2c         W          W  2018-12-24
#
#        deb_interv   nolog  tlog  nbper  ...  FPER31  FPER31MC  FDEP31  FPER36  \
# ...
