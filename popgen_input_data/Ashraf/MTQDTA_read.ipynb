# %%
import pandas as pd
import geopandas as gpd
import numpy as np

emNetLinks = gpd.read_file('/Users/ashrafzaman/matsim_pipelines/DataDonwloaded/FromKinanMTQ/Scenario_2021/emme_links.shp')
emNetNodes = gpd.read_file('/Users/ashrafzaman/matsim_pipelines/DataDonwloaded/FromKinanMTQ/Scenario_2021/emme_nodes.shp')

emNetLinks.to_crs(epsg = 32188, inplace = True)
emNetNodes.to_crs(epsg = 32188, inplace = True)

# %%
emNetNodes.plot()
# Out:
# <AxesSubplot: >

# %%
emNetLinks.plot()
# Out:
# <AxesSubplot: >

# %%
emNetLinks.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 41254 entries, 0 to 41253
# Columns: 167 entries, ID to geometry
# dtypes: float64(161), geometry(1), int64(3), object(2)
# memory usage: 52.6+ MB

# %%
emNetLinks.geometry
# Out:
# 0        LINESTRING (299326.000 5040195.000, 299258.000...
# 1        LINESTRING (299326.000 5040195.000, 299278.000...
# 2        LINESTRING (299326.000 5040195.000, 299368.000...
# 3        LINESTRING (299326.000 5040195.000, 299462.000...
# 4        LINESTRING (300080.000 5038962.000, 299998.000...
#                                ...
# 41249    LINESTRING (307487.000 5035977.000, 307472.000...
# 41250    LINESTRING (307387.000 5035960.000, 307492.000...
# 41251    LINESTRING (307387.000 5035960.000, 307487.000...
# 41252    LINESTRING (307465.000 5036157.000, 307243.000...
# 41253    LINESTRING (307519.000 5036207.000, 307466.000...
# Name: geometry, Length: 41254, dtype: geometry
